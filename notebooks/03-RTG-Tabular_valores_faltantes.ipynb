# %%
# %run 01-RTG-Manejo_de_NAs.ipynb
# Out:
# True
# False
# True
# True
# nan
# False
# True
# nan
# <class 'float'>
# True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37700 entries, 0 to 37699
# Data columns (total 9 columns):
# ...

# %% [markdown]
# # Tabular valores faltantes

# %% [markdown]
# ### Tansformación a valore booleanos.

# %%
riskfactors.isna()
# Out:
#      state    sex    age  weight_lbs  height_inch    bmi  marital  pregnant  \
# 0    False  False  False       False        False  False    False      True
# 1    False  False  False       False        False  False    False      True
# 2    False  False  False       False        False  False    False      True
# 3    False  False  False       False        False  False    False      True
# 4    False  False  False       False        False  False    False      True
# ..     ...    ...    ...         ...          ...    ...      ...       ...
# 240  False  False  False       False        False  False    False      True
# 241  False  False  False       False        False  False    False      True
# 242  False  False  False       False        False  False    False      True
# 243  False  False  False       False        False  False    False      True
# 244  False  False  False       False        False  False    False      True
#
# ...

# %% [markdown]
# ## Resúmenes básicos de valores faltantes

# %% [markdown]
# ## ¿Cuántos datos tenemos?

# %%
riskfactors.shape
# Out:
# (245, 34)

# %% [markdown]
# ### ¿Cuántas son completas?

# %%
riskfactors.missing.na_count()
# Out:
# np.int64(1186)

# %% [markdown]
# ### ¿Proporción de valores faltantes?

# %%
riskfactors.missing.na_proportion()
# Out:
# np.float64(0.14237695078031212)

# %%
riskfactors.missing.na_percentage()
# Out:
# np.float64(14.237695078031212)

# %% [markdown]
# ### ¿Cuántos números completos hay?

# %%
riskfactors.missing.not_na_count()
# Out:
# np.int64(7144)

# %%
riskfactors.missing.not_na_proportion()
# Out:
# np.float64(0.8576230492196879)

# %%
riskfactors.missing.not_na_percentage()
# Out:
# np.float64(85.76230492196879)

# %% [markdown]
# ## Resumentes tabulares de valores faltantes

# %% [markdown]
# ## Variables / columnas
#
# ### Resumenes por variable

# %%
riskfactors.missing.variable_summary()
# Out:
#             variable  n_cases  n_na  n_not_na  na_proportion  na_percentage
# 0              state      245     0       245       0.000000       0.000000
# 1                sex      245     0       245       0.000000       0.000000
# 2                age      245     0       245       0.000000       0.000000
# 3         weight_lbs      245    10       235       0.040816       4.081633
# 4        height_inch      245     2       243       0.008163       0.816327
# 5                bmi      245    11       234       0.044898       4.489796
# 6            marital      245     1       244       0.004082       0.408163
# 7           pregnant      245   215        30       0.877551      87.755102
# 8           children      245     0       245       0.000000       0.000000
# 9          education      245     1       244       0.004082       0.408163
# 10        employment      245     0       245       0.000000       0.000000
# ...

# %% [markdown]
# Es interesante, por ejemplo, que la variable Pregnant tiene un 87% de valores faltantes.

# %%
riskfactors_nas = riskfactors.missing.na_summary()
riskfactors_nas.sort_values(by=['n_variables'], ascending=False)
# Out:
#      n_na  n_variables  prop_of_vars  prc_of_vars
# 0       0         10.0      0.294118    29.411765
# 8       8          6.0      0.176471    17.647059
# 2       2          4.0      0.117647    11.764706
# 3       3          3.0      0.088235     8.823529
# 1       1          2.0      0.058824     5.882353
# 10     10          1.0      0.029412     2.941176
# 11     11          1.0      0.029412     2.941176
# 113   113          1.0      0.029412     2.941176
# 128   128          1.0      0.029412     2.941176
# 134   134          1.0      0.029412     2.941176
# 135   135          1.0      0.029412     2.941176
# 161   161          1.0      0.029412     2.941176
# 212   212          1.0      0.029412     2.941176
# 215   215          1.0      0.029412     2.941176

# %%
sns.barplot(
    data = riskfactors_nas,
    x="n_na",
    y="n_variables"
)
# Out:
# <Axes: xlabel='n_na', ylabel='n_variables'>

# %% [markdown]
# Debemos empezar a sospechar que las variables faltantes tengan relaciones entre sí. Por ejemplo que los valores faltantes en un lugar también falten en otro.

# %% [markdown]
# ## Casos - Observaciones - Filas
# ### Resúmenes por caso

# %%
riskfactors.missing.row_summary()
# Out:
#      case  n_na  n_not_na   prop_na     prc_na
# 0       0     6        28  0.176471  17.647059
# 1       1     6        28  0.176471  17.647059
# 2       2     7        27  0.205882  20.588235
# 3       3    12        22  0.352941  35.294118
# 4       4     5        29  0.147059  14.705882
# ..    ...   ...       ...       ...        ...
# 240   240     6        28  0.176471  17.647059
# 241   241     5        29  0.147059  14.705882
# 242   242     3        31  0.088235   8.823529
# 243   243     2        32  0.058824   5.882353
# 244   244     3        31  0.088235   8.823529
#
# [245 rows x 5 columns]

# %%
riskfactors.missing.missing_case_summary()
# Out:
#      case  n_na  n_not_na   prop_na     prc_na
# 0       0     6        28  0.176471  17.647059
# 1       1     6        28  0.176471  17.647059
# 2       2     7        27  0.205882  20.588235
# 3       3    12        22  0.352941  35.294118
# 4       4     5        29  0.147059  14.705882
# ..    ...   ...       ...       ...        ...
# 240   240     6        28  0.176471  17.647059
# 241   241     5        29  0.147059  14.705882
# 242   242     3        31  0.088235   8.823529
# 243   243     2        32  0.058824   5.882353
# 244   244     3        31  0.088235   8.823529
#
# [245 rows x 5 columns]

# %% [markdown]
# ## Intervalos de valores faltantes

# %%
riskfactors.missing.missing_case_summary()
# Out:
#      case  n_na  n_not_na   prop_na     prc_na
# 0       0     6        28  0.176471  17.647059
# 1       1     6        28  0.176471  17.647059
# 2       2     7        27  0.205882  20.588235
# 3       3    12        22  0.352941  35.294118
# 4       4     5        29  0.147059  14.705882
# ..    ...   ...       ...       ...        ...
# 240   240     6        28  0.176471  17.647059
# 241   241     5        29  0.147059  14.705882
# 242   242     3        31  0.088235   8.823529
# 243   243     2        32  0.058824   5.882353
# 244   244     3        31  0.088235   8.823529
#
# [245 rows x 5 columns]

# %% [markdown]
# ## Obtener tabla de valores faltantes por span

# %%
riskfactors.missing.row_summary(50)
# Out:
#    span   n_na  n_not_na   prop_na     prc_na
# 0     0  254.0    1446.0  0.149412  14.941176
# 1     1  250.0    1450.0  0.147059  14.705882
# 2     2  257.0    1443.0  0.151176  15.117647
# 3     3  222.0    1478.0  0.130588  13.058824
# 4     4  203.0    1327.0  0.132680  13.267974

# %%
riskfactors[['weight_lbs']].missing.row_summary(50)
# Out:
#    span  n_na  n_not_na   prop_na     prc_na
# 0     0   1.0      49.0  0.020000   2.000000
# 1     1   5.0      45.0  0.100000  10.000000
# 2     2   1.0      49.0  0.020000   2.000000
# 3     3   1.0      49.0  0.020000   2.000000
# 4     4   2.0      43.0  0.044444   4.444444

# %% [markdown]
# Es recomendable observar el conjunto de datos buscando los intervalos de datos de los que podrian provenir los datos faltantes.

# %%
riskfactors.missing.streaks("weight_lbs")
# Out:
# /home/changery/Platzi/016-Manejo_de_NAs/notebooks/scripts/pandas_missing_extension.py:166: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   case = self._df[[var]].iloc[i].isna().bool()
# /home/changery/Platzi/016-Manejo_de_NAs/notebooks/scripts/pandas_missing_extension.py:166: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   case = self._df[[var]].iloc[i].isna().bool()
# /home/changery/Platzi/016-Manejo_de_NAs/notebooks/scripts/pandas_missing_extension.py:166: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   case = self._df[[var]].iloc[i].isna().bool()
# /home/changery/Platzi/016-Manejo_de_NAs/notebooks/scripts/pandas_missing_extension.py:166: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   case = self._df[[var]].iloc[i].isna().bool()
# ...

# %% [markdown]
# Deben encontrarse los picos donde estén encontrandose grandes picos de racha de valores faltantes. Esto significa que algo en ese momento alteró el comportamiento de las mediciones.

# %% [markdown]
# ## Exploraciones visuales básicas
#
# ### El uso de porcentaje de faltantes por variable

# %%
riskfactors_na_vars = riskfactors.missing.variable_summary().sort_values(by="n_na", ascending=False)

sns.barplot(
    data = riskfactors_na_vars,
    y = "variable",
    x = "na_percentage"
)
plt.xlabel("% de valores faltantes")
plt.ylabel("Variable")
# Out:
# Text(0, 0.5, 'Variable')

# %% [markdown]
# Eventualmente una tabla se vuelve insuficiente
#
# ## Observar valores que conjuntamente aparecen faltantes.

# %%
sns.heatmap(
    riskfactors.isna()
)
# Out:
# <Axes: >

# %% [markdown]
# Puede observarse que pregnant tiene muchos valores faltantes, además debe observarse que hay valores cuyo contexto está muy relacionado, y cuando una no aplica, el resto tampoco (como el smoke o el drink).

# %%
riskfactors.missing.row_summary()[["n_na"]].value_counts().to_frame().reset_index()
# Out:
#     n_na  count
# 0      4     49
# 1      5     45
# 2      7     39
# 3      6     36
# 4      2     31
# 5      3     30
# 6      1      4
# 7      8      3
# 8     12      3
# 9     15      2
# 10     9      1
# 11    11      1
# 12    10      1

# %%
riskfactors.missing.row_summary()[["n_na"]].value_counts().to_frame().reset_index().pipe(
    lambda data : sns.barplot(data, y="count", x="n_na")
)
plt.xlabel("Número de NA en el registro")
plt.ylabel("Número de casos")
# Out:
# Text(0, 0.5, 'Número de casos')

# %%
riskfactors.missing.row_summary(50)[["prc_na"]].reset_index()
# Out:
#    index     prc_na
# 0      0  14.941176
# 1      1  14.705882
# 2      2  15.117647
# 3      3  13.058824
# 4      4  13.267974

# %%
span = 10

riskfactors.missing.row_summary(span)[["prc_na"]].reset_index().pipe(
    lambda data : sns.barplot(data, x="index", y="prc_na")
)
plt.xlabel(f"Intervalo de {span}")
plt.ylabel("% de NA")
plt.ylim([0, 80])
# Out:
# (0.0, 80.0)

# %%
riskfactors.missing.row_summary()[["prc_na"]].reset_index().pipe(
    lambda data : sns.histplot(data, x="prc_na", binwidth=7
)
)
plt.xlabel(f"Intervalo de {span}")
plt.ylabel("% de NA")
plt.ylim([0, 80])
# Out:
# (0.0, 80.0)

# %% [markdown]
# Es útil observar si hay intervalos particularmente altos en valores faltantes.

# %% [markdown]
# En ocasiones ya hay librerías que ayudan a manejar valores faltanes.

# %%
missingno.bar(df = riskfactors)
# Out:
# <Axes: >

# %% [markdown]
# La visualización anterior muestra la proporción de filas con valores faltantes.

# %%
missingno.matrix(df = riskfactors)
# Out:
# <Axes: >

# %% [markdown]
# Para entender si regresan de los mismos valores faltantes

# %% [markdown]
# Para conocer la correlación

# %%
missingno.heatmap(riskfactors)
# Out:
# <Axes: >
